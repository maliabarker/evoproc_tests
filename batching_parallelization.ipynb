# %% [markdown]
# ## Import libraries/packages

# %% [markdown]
# **Before starting**
#
# Run the command ``OLLAMA_NUM_PARALLEL=8 OLLAMA_MAX_LOADED_MODELS=1 ollama serve``
#
# This will get OLLama up and running

# %%
import time
import json

import pandas as pd

from __future__ import annotations

from evoproc_procedures.runners import run_steps_stateful_minimal
from evoproc_procedures.schemas import get_schema

from step_run_and_mp import MPBatchOllamaEngine, make_batched_query_fn

# %%
UNITS = 4
MODEL = "gpt-oss:120b"
SEED = 1234
FINAL_SCHEMA = get_schema("gsm")
PRINT_BOOL = False

PROC_RESULTS_FILEPATH = "runs/gsm8k_train_v6.jsonl"
BASELINE_RESULTS_FILEPATH = "runs/gsm8k_train_v6_baseline.jsonl"

# %% [markdown]
# ## Reading in the result files

# %%
read_results = None
with open(PROC_RESULTS_FILEPATH, "r") as f:
    items = [json.loads(line) for line in f if line.startswith("//") is False]
    read_results = items
    f.close()
proc_results_df = pd.DataFrame(read_results)

# %%
read_results = None
with open(BASELINE_RESULTS_FILEPATH, "r") as f:
    items = [json.loads(line) for line in f if line.startswith("//") is False]
    read_results = items
    f.close()
baseline_results_df = pd.DataFrame(read_results)

# %% [markdown]
# ## For each procedure:
# - Grab the procedure
# - For each step
#     - Run the step prompt N times
#     - Choose the most consistent final answer

# %%
# Conditions and their descriptions are included in data_exploration.ipynb file
condition1_final = [22, 48, 81, 136, 173]
condition2_final = [31, 52, 59, 65, 183, 193, 196, 200, 210, 240, 243, 245, 264]
condition3_final = [13, 63, 95, 103, 113, 142, 181, 187, 190, 220, 230, 237, 242, 267, 274]
condition4_final = [144, 234]
condition5_final = [108, 167, 218, 228, 229, 235, 270]

repairable = condition1_final + condition2_final + condition4_final
repairable_df = proc_results_df.iloc[repairable]
irreparable = condition3_final
irreparable_df = proc_results_df.iloc[irreparable]
# Note: condition 5 are actually correct, but the DB answers are incorrect themselves

# %%
engine = MPBatchOllamaEngine(model=MODEL, units=UNITS)
QUERY_FN = make_batched_query_fn(
    engine,
    n=4,                 # samples per step
    strategy="consensus" # or "pick_best"
)

GPT_OSS_LOCAL_BUGGY_MODELS = {"gpt-oss:20b", "gpt-oss:120b"}
def query_fn_no_format_for_gptoss(prompt, model, fmt, seed):
    # kill structured-output / format only for gpt-oss models
    # Note, this will only be with the gpt-oss NON-CLOUD models (gpt-oss:120b & gpt-oss:20b)
    # Cloud models do not have this bug, so I want to bypass this if it is a cloud model
    if isinstance(model, str) and model in GPT_OSS_LOCAL_BUGGY_MODELS:
        fmt = None
    return QUERY_FN(prompt, model, fmt, seed)   # call your existing function

# %%
for i, row in repairable_df.iterrows():
    try:
        start_time = time.time()
        state = run_steps_stateful_minimal(
            proc=row["procedure"],
            problem_text=row["question"],
            answer_schema=FINAL_SCHEMA,
            model=MODEL,
            query_fn=query_fn_no_format_for_gptoss,
            seed=SEED,
            print_bool=PRINT_BOOL,
            strict_missing=True,
        )
        end_time = time.time()
        correct = state["final_answer_numerical"] == row["gold_num"]
        this_print_bool = True
        if this_print_bool:
            print(f"Finished {i+1}/{len(repairable)}")
            print(f"Time taken: {end_time - start_time:.2f} seconds")
            correct = state["final_answer_numerical"] == row["gold_num"]
            if row["correct"] == correct:
                print("NO CHANGE. Correctness matches the expected value.")
            if not row["correct"] and correct:
                print("Model got it right this time, was marked wrong in the results file.")
                print(f"State: {state}")
                print(f"Is final answer correct? {state['final_answer_numerical'] == row['gold_num']}")
            if row["correct"] and not correct:
                print("Model got it wrong this time, was marked correct in the results file.")
                print(f"State: {state}")
                print(f"Is final answer correct? {state['final_answer_numerical'] == row['gold_num']}")
            if not row["correct"] and not correct:
                print("Model got it wrong this time, was marked wrong in the results file.")
                print(f"State: {state}")
                print(f"Is final answer correct? {state['final_answer_numerical'] == row['gold_num']}")
    except Exception as e:
        print(f"An error occurred: {e}")
# Out:
# Finished 23/20
# Time taken: 93.01 seconds
# NO CHANGE. Correctness matches the expected value.
# Model got it wrong this time, was marked wrong in the results file.
# State: {'problem_text': 'Samantha’s last name has three fewer letters than Bobbie’s last name. If Bobbie took two letters off her last name, she would have a last name twice the length of Jamie’s. Jamie’s full name is Jamie Grey. How many letters are in Samantha’s last name?', 'diff_sam_bob': 3, 'bob_removed': 2, 'factor': 2, 'jamie_last_len': 4, 'bob_length_expr': '2 * jamie_last_len + 2', 'samantha_length_expr': '2 * jamie_last_len - 1', 'final_answer': "Samantha's last name length is 9.", 'final_answer_numerical': 9, 'confidence': 0.4}
# Is final answer correct? False
# Finished 49/20
# Time taken: 58.49 seconds
# NO CHANGE. Correctness matches the expected value.
# Model got it wrong this time, was marked wrong in the results file.
# State: {'problem_text': 'Sam memorized six more digits of pi than Carlos memorized. Mina memorized six times as many digits of pi as Carlos memorized. If Mina memorized 24 digits of pi, how many digits did Sam memorize?', 'six': 6, 'mina_digits': 24, 'carlos_digits': 4, 'sam_digits': 'carlos_digits + six', 'final_answer': "Sam's digit count is 6.", 'final_answer_numerical': 6, 'confidence': 0.78}
# Is final answer correct? False
# Finished 82/20
# Time taken: 68.78 seconds
# NO CHANGE. Correctness matches the expected value.
# Model got it wrong this time, was marked wrong in the results file.
# State: {'problem_text': 'Sam and Jeff had a skipping competition at recess. The competition was split into four rounds. Sam completed 1 more skip than Jeff in the first round. Jeff skipped 3 fewer times than Sam in the second round. Jeff skipped 4 more times than Sam in the third round. Jeff got tired and only completed half the number of skips as Sam in the last round. If Sam skipped 16 times in each round, what is the average number of skips per round completed by Jeff?', 'sam_skips_per_round': 16, 'rounds': 4, 'diff_round1': 1, 'diff_round2': 3, 'diff_round3': 4, 'ratio_round4': 2, 'jeff_round1': 15, 'jeff_round2': 13, 'jeff_round3': 20, 'jeff_round4': 16, 'final_answer': "Jeff's average skips per round is 16.", 'final_answer_numerical': 16, 'confidence': 1.0}
# Is final answer correct? False
# Finished 137/20
# Time taken: 110.90 seconds
# NO CHANGE. Correctness matches the expected value.
# Model got it wrong this time, was marked wrong in the results file.
# State: {'problem_text': 'Loraine makes wax sculptures of animals. Large animals take four sticks of wax and small animals take two sticks. She made three times as many small animals as large animals, and she used 12 sticks of wax for small animals. How many sticks of wax did Loraine use to make all the animals?', 'sticks_per_large': 4, 'sticks_per_small': 2, 'small_to_large_ratio': 3, 'sticks_small_used': 12, 'large_animals': 'sticks_small_used / (small_to_large_ratio * sticks_per_small)', 'small_animals': 'sticks_small_used / sticks_per_small', 'final_answer': 'The total number of sticks used is 0.', 'final_answer_numerical': 0, 'confidence': 0.78}
# Is final answer correct? False
# Finished 174/20
# Time taken: 34.78 seconds
# NO CHANGE. Correctness matches the expected value.
# Model got it wrong this time, was marked wrong in the results file.
# State: {'problem_text': "Mark has two pets, a hare that runs 10 feet/second and a turtle that crawls 1 foot/second. If they're going to run a 20 foot-race, how much of a head start (in seconds) does the turtle need to finish in a tie?", 'hare_speed': 10, 'turtle_speed': 1, 'race_distance': 20, 'hare_time': 2, 'turtle_time': '20 + head_start', 'final_answer': 'Setting hare_time equal to turtle_time gives 2 = 20 + head_start, so head_start = -18.', 'final_answer_numerical': -18, 'confidence': 1.0}
# Is final answer correct? False
# Finished 32/20
# Time taken: 70.12 seconds
# NO CHANGE. Correctness matches the expected value.
# Model got it wrong this time, was marked wrong in the results file.
# State: {'problem_text': 'Noah is a painter. He paints pictures and sells them at the park. He charges $60 for a large painting and $30 for a small painting. Last month he sold eight large paintings and four small paintings. If he sold twice as much this month, how much is his sales for this month?', 'large_price': 60, 'small_price': 30, 'large_sold_last': 8, 'small_sold_last': 4, 'multiplier': 2, 'last_month_sales': 'large_price * large_sold_last + small_price * small_sold_last', 'this_month_sales': '2 * (large_price * large_sold_last + small_price * small_sold_last)', 'final_answer': 'The symbolic value of this_month_sales is 2 * (large_price * large_sold_last + small_price * small_sold_last).', 'final_answer_numerical': 0, 'confidence': 0.2}
# Is final answer correct? False
# Finished 53/20
# Time taken: 44.98 seconds
# Model got it right this time, was marked wrong in the results file.
# State: {'problem_text': 'Arnel had ten boxes of pencils with the same number of pencils in each box.  He kept ten pencils and shared the remaining pencils equally with his five friends. If his friends got eight pencils each, how many pencils are in each box?', 'num_boxes': 10, 'kept_pencils': 10, 'num_friends': 5, 'pencils_per_friend': 8, 'pencils_per_box': '(10 + 8 * 5) / 10', 'final_answer': 'The result of (10 + 8 * 5) / 10 is 5.', 'final_answer_numerical': 5, 'confidence': 1.0}
# Is final answer correct? True
# Finished 60/20
# Time taken: 31.41 seconds
# NO CHANGE. Correctness matches the expected value.
# Model got it wrong this time, was marked wrong in the results file.
# State: {'problem_text': 'Every hour Joanne has to collect the coins out of the fountain inside the mall. During the first hour, she collected 15 coins. For the next two hours, she collected 35 coins from the fountain. In the fourth hour, she collected 50 coins from the fountain but she gave 15 of them to her coworker so she could buy a soda. How many coins did she have after the fourth hour?', 'first_hour_coins': 15, 'next_two_hours_coins': 35, 'fourth_hour_collected': 50, 'given_to_coworker': 15, 'total_coins': 85, 'final_answer': 'The computed total is 85.', 'final_answer_numerical': 85, 'confidence': 1.0}
# Is final answer correct? False
# Finished 66/20
# Time taken: 69.26 seconds
# NO CHANGE. Correctness matches the expected value.
# Model got it wrong this time, was marked wrong in the results file.
# State: {'problem_text': 'Lee mows one lawn and charges $33. Last week he mowed 16 lawns and three customers each gave him a $10 tip. How many dollars did Lee earn mowing lawns last week?', 'charge_per_lawn': 33, 'lawns_mowed': 16, 'num_customers': 3, 'tip_per_customer': 10, 'total_earnings_from_lawns': 'total_earnings_from_lawns = lawns_mowed * charge_per_lawn', 'total_tips': 'total_tips = num_customers * tip_per_customer', 'final_answer': 'The combined total of earnings and tips is 0.', 'final_answer_numerical': 0, 'confidence': 0.2}
# Is final answer correct? False
# Finished 184/20
# Time taken: 74.36 seconds
# NO CHANGE. Correctness matches the expected value.
# Model got it wrong this time, was marked wrong in the results file.
# State: {'problem_text': 'A small poultry farm has 300 chickens, 200 turkeys and 80 guinea fowls. A strange, incurable disease hit the farm and every day the farmer lost 20 chickens, 8 turkeys and 5 guinea fowls. After a week, how many birds will be left in the poultry?', 'init_chickens': 300, 'init_turkeys': 200, 'init_guinea_fowls': 80, 'loss_chickens_per_day': 20, 'loss_turkeys_per_day': 8, 'loss_guinea_fowls_per_day': 5, 'days': 7, 'total_initial': 580, 'total_daily_loss': 'loss_chickens_per_day + loss_turkeys_per_day + loss_guinea_fowls_per_day', 'final_answer': 'After 7 days, the remaining number of birds is 580.', 'final_answer_numerical': 580, 'confidence': 0.7}
# Is final answer correct? False
# Finished 194/20
# Time taken: 55.45 seconds
# NO CHANGE. Correctness matches the expected value.
# Model got it wrong this time, was marked wrong in the results file.
# State: {'problem_text': 'Melody planted sunflowers from two different seed packets. She found that the sunflowers from Packet A were 20% taller than the sunflowers from Packet B. If the sunflowers from Packet A were 192 inches tall, how tall were the sunflowers from Packet B?', 'percent_difference': 20, 'height_a': 192, 'height_b': 'height_a / (1 + percent_difference/100)', 'final_answer': 'The required height of Packet B sunflowers is given by height_b = height_a / (1 + percent_difference/100).', 'final_answer_numerical': 0, 'confidence': 0.0}
# Is final answer correct? False
# Finished 197/20
# Time taken: 64.69 seconds
# NO CHANGE. Correctness matches the expected value.
# Model got it wrong this time, was marked wrong in the results file.
# State: {'problem_text': 'Herbert is 10 years younger than Kris. If Kris is 24 years old now, how old will Herbert be next year?', 'herbert_younger_by': 10, 'kris_current_age': 24, 'herbert_current_age': 'kris_current_age - herbert_younger_by', 'final_answer': "Herbert's age next year cannot be determined from the given information; assuming unknown values, the result is 0.", 'final_answer_numerical': 0, 'confidence': 0.2}
# Is final answer correct? False
# Finished 201/20
# Time taken: 72.82 seconds
# NO CHANGE. Correctness matches the expected value.
# Model got it wrong this time, was marked wrong in the results file.
# State: {'problem_text': 'Sansa is a famous artist, she can draw a portrait and sell it according to its size. She sells an 8-inch portrait for $5, and a 16-inch portrait for twice the price of the 8-inch portrait. If she sells three 8-inch portraits and five 16-inch portraits per day, how many does she earns every 3 days?', 'size_8_inch': 8, 'price_8': 5, 'size_16_inch': 16, 'price_factor_16': 2, 'count_8_daily': 3, 'count_16_daily': 5, 'days_interval': 3, 'price_16': 'price_factor_16 * price_8', 'daily_earnings': '15 + 25 * price_factor_16', 'final_answer': 'The total earnings over 3 days is 1245.', 'final_answer_numerical': 1245, 'confidence': 0.99}
# Is final answer correct? False
# Finished 211/20
# Time taken: 51.58 seconds
# NO CHANGE. Correctness matches the expected value.
# Model got it wrong this time, was marked wrong in the results file.
# State: {'problem_text': 'Bobby has 16 toy cars, and the number of cars he has increases by 50% every year. How many toy cars will Bobby have in three years?', 'initial_cars': 16, 'growth_rate': 0.5, 'years': 3, 'growth_factor': 1.5, 'final_cars': 'initial_cars * (growth_factor ** years)', 'final_answer': 'final_answer = initial_cars * (growth_factor ** years)', 'final_answer_numerical': 0, 'confidence': 0.2}
# Is final answer correct? False
# Finished 241/20
# Time taken: 68.07 seconds
# NO CHANGE. Correctness matches the expected value.
# Model got it wrong this time, was marked wrong in the results file.
# State: {'problem_text': 'Kate bought 7 packs of red bouncy balls and 6 packs of yellow bouncy balls. Each pack contained 18 bouncy balls. How many more red bouncy balls than yellow bouncy balls did Kate buy?', 'red_packs': 7, 'yellow_packs': 6, 'balls_per_pack': 18, 'total_red': '7*18', 'total_yellow': 'yellow_packs * balls_per_pack', 'final_answer': 'The difference cannot be determined because the values for yellow_packs and balls_per_pack are not provided; total red is 126, so the difference is 126 - (yellow_packs * balls_per_pack).', 'final_answer_numerical': 0, 'confidence': 0.1}
# Is final answer correct? False
# Finished 244/20
# Time taken: 48.38 seconds
# Model got it right this time, was marked wrong in the results file.
# State: {'problem_text': 'Mckenna starts her day at 8:00 a.m. She works in her office up to 11:00 a.m. then joins her team of developers at the conference room to talk about projects up to 13:00, from which she works for another two hours and then heads home. How many hours does Mckenna stay at work?', 'start_time': 8, 'morning_work_end': 11, 'conference_end': 13, 'afternoon_work_duration': 2, 'total_time': '(11 - 8) + (13 - 11) + 2', 'final_answer': 'The total time is 7', 'final_answer_numerical': 7, 'confidence': 1.0}
# Is final answer correct? True
# Finished 246/20
# Time taken: 48.54 seconds
# Model got it right this time, was marked wrong in the results file.
# State: {'problem_text': 'There are 12 crates that each contain 150 oranges. There are 16 boxes that each hold 30 nectarines. How many pieces of fruit are in the crates and the boxes in total?', 'crates_count': 12, 'oranges_per_crate': 150, 'boxes_count': 16, 'nectarines_per_box': 30, 'total_oranges': '12 * 150', 'total_nectarines': '16 * 30', 'final_answer': 'The overall fruit count is 2280.', 'final_answer_numerical': 2280, 'confidence': 1.0}
# Is final answer correct? True
# Finished 265/20
# Time taken: 63.92 seconds
# NO CHANGE. Correctness matches the expected value.
# Model got it wrong this time, was marked wrong in the results file.
# State: {'problem_text': 'An Italian restaurant earns $600 every weekday and twice as much on the weekend. How much money does it earn by the end of the month?', 'weekday_earnings': 600, 'weekend_multiplier': 2, 'num_weekdays': 'n_weekdays', 'num_weekend_days': 'n_weekend_days', 'weekend_earnings_per_day': 1200, 'total_earnings': '600 * n_weekdays + 1200 * n_weekend_days', 'final_answer': 'The total earnings are given by 600 * n_weekdays + 1200 * n_weekend_days.', 'final_answer_numerical': 0, 'confidence': 0.2}
# Is final answer correct? False
# Finished 145/20
# Time taken: 57.49 seconds
# NO CHANGE. Correctness matches the expected value.
# Model got it wrong this time, was marked wrong in the results file.
# State: {'problem_text': 'The owner of a Turkish restaurant wanted to prepare traditional dishes for an upcoming celebration. She ordered ground beef, in four-pound packages, from three different butchers. The following morning, the first butcher delivered 10 packages. A couple of hours later, 7 packages arrived from the second butcher. Finally, the third butcher’s delivery arrived at dusk. If all the ground beef delivered by the three butchers weighed 100 pounds, how many packages did the third butcher deliver?', 'package_weight': 4, 'first_packages': 10, 'second_packages': 7, 'total_weight': 100, 'third_packages': 'total_weight / package_weight - first_packages - second_packages', 'final_answer': 'The value of third_packages cannot be determined from the given information, resulting in 0.', 'final_answer_numerical': 0, 'confidence': 0.0}
# Is final answer correct? False
# Finished 235/20
# Time taken: 58.83 seconds
# Model got it right this time, was marked wrong in the results file.
# State: {'problem_text': 'Mark buys a loaf of bread for $4.20 and some cheese for $2.05. He gives the cashier $7.00. If the cashier only has 1 quarter and 1 dime in his till, plus a bunch of nickels, how many nickels does Mark get in his change?', 'bread_price': 4.2, 'cheese_price': 2.05, 'cash_given': 7.0, 'quarter_value': 0.25, 'dime_value': 0.1, 'nickel_value': 0.05, 'total_cost': 6.25, 'change_due': 0.75, 'known_coins_value': 0.35, 'nickels_value': 0.4, 'final_answer': 'The number of nickels needed is 8.', 'final_answer_numerical': 8, 'confidence': 1.0}
# Is final answer correct? True

# %% [markdown]
# Questions that were corrected with SC runs:
# - 23, 32, 49
#
# Questions that are still incorrect:
# - 14, 53, 60, 64, 66, 82, 96, 104

# %%
import multiprocess as mp
import numpy as np

units=4

import platform

if platform.system() == "Darwin": # Check if the OS is macOS
    mp.set_start_method("spawn", force=True)

# %%
def ola(x):
    model1 = "gpt-oss:20b"
    import ollama
    l=[]
    for z in x:
        l.append(ollama.generate(model=model1,prompt=z,stream=False)['response']) 
    return l

def generate(list):
    vec=np.array(list)
    li=[]
    amount=int(vec.shape[0]/units)
    j=0
    for i in range(units-1):
        li.append(vec[j*amount:(j+1)*amount])
        j=j+1
    li.append(vec[j*amount:vec.shape[0]])
    print(li)
    with mp.Pool(units) as pool:
        x=pool.map(ola, li)
    lf=[]
    for t in x:
        lf.extend(t)
    return lf

# %%
generate(["What is 2+2?", "What is the capital of France?", "Who wrote 'To Kill a Mockingbird'?", "What is the boiling point of water?"])
# Out:
# [array(['What is 2+2?'], dtype='<U35'), array(['What is the capital of France?'], dtype='<U35'), array(["Who wrote 'To Kill a Mockingbird'?"], dtype='<U35'), array(['What is the boiling point of water?'], dtype='<U35')]
# ['4',
#  'The capital of France is **Paris**.',
#  '"To Kill a Mockingbird" was written by **Harper Lee**.',
#  'The normal boiling point of water—meaning the temperature at which its vapor pressure equals the surrounding atmospheric pressure of 1\u202fatmosphere—is:\n\n- **100\u202f°C** (\u202f212\u202f°F\u202f)  \n- **373.15\u202fK**  \n\n**A few extra points to keep in mind**\n\n| Factor | Effect on Boiling Point | Typical Change |\n|--------|------------------------|----------------|\n| **Altitude / pressure** | Lower atmospheric pressure lowers the boiling point. | At 2\u202f000\u202fm (≈\u202f65\u202fkPa), water boils at ≈\u202f93\u202f°C. |\n| **Impurities / solutes** | Dissolved solutes (like salt) raise the boiling point slightly (boiling‑point elevation). | A 3\u202f% NaCl solution boils at ≈\u202f100.9\u202f°C. |\n| **Pressure** | Increasing external pressure raises the boiling point. | At 2\u202fatm (≈\u202f202\u202fkPa), water boils at ≈\u202f120\u202f°C. |\n| **Pseudocode (if you want to calculate it)** |\n```python\ndef boiling_point_at_pressure(P):  # P in kPa\n    # Rough linear interpolation between 1 atm (101.325 kPa) and 2 atm\n    if P < 101.325:\n        return 100.0 - 0.5 * (101.325 - P) / 101.325 * 100  # crude\n    else:\n        return 100.0 + 20.0 * (P - 101.325) / 101.325\n```\n(For precise values you’d use the Antoine equation or steam tables.)\n\nIn everyday contexts—like cooking on a standard stovetop—the canonical answer is **100\u202f°C (373.15\u202fK)**.']
